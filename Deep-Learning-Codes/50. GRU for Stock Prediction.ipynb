# %% [markdown]
# Import necessary libraries

# %%
import numpy as np  # For numerical operations
import pandas as pd  # For data manipulation
import matplotlib.pyplot as plt  # For visualization
from sklearn.preprocessing import MinMaxScaler  # For normalizing data
from tensorflow.keras.models import Sequential  # For defining the GRU model
from tensorflow.keras.layers import GRU, Dense  # GRU and Dense layers
from tensorflow.keras.optimizers import Adam  # Optimizer for gradient descent

# %% [markdown]
# Generate synthetic stock price data

# %%
np.random.seed(42)
time_steps = 100  # Number of time steps
price = np.cumsum(np.random.randn(time_steps) * 2) + 100  # Simulating stock prices using a random walk

df = pd.DataFrame(price, columns=["Stock Price"])  # Creating a DataFrame

# %% [markdown]
# Visualizing the stock price data

# %%
plt.plot(df, label='Stock Price')
plt.xlabel('Time Step')
plt.ylabel('Price')
plt.title('Synthetic Stock Price Data')
plt.legend()
plt.show()

# %% [markdown]
# Prepare data for GRU

# %%
# Normalize the data to scale between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(df)

# Prepare data for GRU
X, y = [], []
n_steps = 10  # Number of previous time steps to consider

# %% [markdown]
# Gated Recurrent Unit (GRU) processes sequential data by maintaining a hidden state:
#
#     The GRU cell consists of two main gates:
#         1. Update Gate: z_t = σ(W_z * [h_(t-1), x_t] + b_z)
#         2. Reset Gate: r_t = σ(W_r * [h_(t-1), x_t] + b_r)
#     The hidden state is updated as:
#         h_t = (1 - z_t) * h_(t-1) + z_t * tanh(W_h * [r_t * h_(t-1), x_t] + b_h)

# %%
for i in range(len(data_scaled) - n_steps):
    X.append(data_scaled[i:i + n_steps])  # Input sequence of length 'n_steps'
    y.append(data_scaled[i + n_steps])  # Corresponding output

X, y = np.array(X), np.array(y)

# %% [markdown]
# Split data into training and testing sets

# %%
split_ratio = 0.8  # 80% training, 20% testing
split_index = int(len(X) * split_ratio)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# %% [markdown]
# Define the GRU model

# %%
model = Sequential([
    GRU(50, activation='tanh', return_sequences=False, input_shape=(n_steps, 1)),  # GRU layer with 50 units
    # The activation function tanh is defined as:
    # tanh(x) = (e^x - e^(-x)) / (e^x + e^(-x))
    # It helps maintain gradients and avoid vanishing gradient problems.
    Dense(1)  # Output layer with a single neuron for price prediction
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Compile and train the model

# %%
# Compile the model
# The loss function used is Mean Squared Error (MSE):
# MSE = (1/n) * Σ (y_true - y_pred)^2
# where n is the number of samples
model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 0.0608 - val_loss: 0.0039
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0106 - val_loss: 0.0023
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0040 - val_loss: 0.0023
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - val_loss: 0.0028
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0033 - val_loss: 0.0021
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0038 - val_loss: 0.0020
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0035 - val_loss: 0.0020
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0035 - val_loss: 0.0024
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033 - val_loss: 0.0020
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0028 - val_loss: 0.0018
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - val_loss: 0.0017
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - val_loss: 0.0018
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0030 - val_loss: 0.0021
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0037 - val_loss: 0.0024
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0037 - val_loss: 0.0016
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0033 - val_loss: 0.0019
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0041 - val_loss: 0.0017
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0045 - val_loss: 0.0016
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0023 - val_loss: 0.0016
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - val_loss: 0.0019
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0034 - val_loss: 0.0017
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0029 - val_loss: 0.0016
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0029 - val_loss: 0.0019
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0036 - val_loss: 0.0016
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0037 - val_loss: 0.0027
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - val_loss: 0.0017
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0026 - val_loss: 0.0015
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0025 - val_loss: 0.0016
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0038 - val_loss: 0.0016

# %% [markdown]
# Predict on the test set

# %%
# Predict on the test set
y_pred = model.predict(X_test)

# Convert predictions back to original scale
y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_actual = scaler.inverse_transform(y_pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step

# %% [markdown]
# Plot actual vs predicted stock prices

# %%
plt.figure(figsize=(10, 5))
plt.plot(y_test_actual, label='Actual Stock Price', linestyle='dashed')
plt.plot(y_pred_actual, label='Predicted Stock Price', alpha=0.7)
plt.xlabel('Time Step')
plt.ylabel('Stock Price')
plt.title('GRU Stock Price Prediction')
plt.legend()
plt.show()
